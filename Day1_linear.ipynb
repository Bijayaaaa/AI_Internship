# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.axes as ax
from matplotlib.animation import FuncAnimation
from sklearn import linear_model

# %%
df=pd.read_csv("D:/AI internship/archive (2)/test.csv")
df
# Out:
#       x          y
# 0    77  79.775152
# 1    21  23.177279
# 2    22  25.609262
# 3    20  17.857388
# 4    36  41.849864
# ..   ..        ...
# 295  71  68.545888
# 296  46  47.334876
# 297  55  54.090637
# 298  62  63.297171
# 299  47  52.459467
#
# [300 rows x 2 columns]

# %%
# %matplotlib inline
plt.xlabel('x')
plt.ylabel('y')
plt.scatter(df.x,df.y,color='green',marker='.')

# %%
reg=linear_model.LinearRegression()
reg.fit(df[['x']],df.y)
# Out:
# LinearRegression()

# %%
reg.predict([[10]])
# Out:
# D:\AI internship\ai_intern\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([9.68154278])

# %%
reg.coef_
# Out:
# array([1.01433536])

# %%
reg.intercept_
# Out:
# np.float64(-0.4618107736611847)

# %%
  1.01433536*10+-0.4618107736611847
# Out:
# 9.681542826338816

# %%
test_df=pd.read_csv("D:/AI internship/archive (2)/test.csv")
test_df
# Out:
#       x
# 0    77
# 1    21
# 2    22
# 3    20
# 4    36
# ..   ..
# 295  71
# 296  46
# 297  55
# 298  62
# 299  47
#
# [300 rows x 1 columns]

# %%
p=reg.predict(test_df)
p
# Out:
# array([ 77.64201157,  20.83923168,  21.85356704,  19.82489633,
#         36.05426201,  14.75321955,  62.42698124,  95.90004796,
#         19.82489633,   4.609866  ,   3.59553065,  18.81056097,
#         96.91438332,  62.42698124,  36.05426201,  14.75321955,
#         65.46998731,  13.7388842 ,  87.78536512,  69.52732873,
#         89.81403583,  51.26929234,  89.81403583,  26.92524381,
#         97.92871867,  58.36963982,  79.67068228,  20.83923168,
#         93.87137725,  26.92524381,  99.95738938,  30.98258524,
#         33.01125595,  80.68501764,  27.93957917,  47.21195092,
#         53.29796305,  69.52732873,  27.93957917,  33.01125595,
#         91.84270654,  71.55599944,  50.25495698,  76.62767622,
#          3.59553065,  37.06859737,  70.54166408,  68.51299337,
#         40.11160343,  35.03992666,  94.88571261,  88.79970048,
#         52.28362769,  30.98258524,  59.38397518,  -0.46181077,
#         39.09726808,  64.45565195,  69.52732873,  57.35530447,
# ...

# %%
test_df['y']=p
test_df
# Out:
#       x          y
# 0    77  77.642012
# 1    21  20.839232
# 2    22  21.853567
# 3    20  19.824896
# 4    36  36.054262
# ..   ..        ...
# 295  71  71.555999
# 296  46  46.197616
# 297  55  55.326634
# 298  62  62.426981
# 299  47  47.211951
#
# [300 rows x 2 columns]
